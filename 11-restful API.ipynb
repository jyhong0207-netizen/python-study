# %%
import requests
from pandas import DataFrame

# %%
with requests.Session()as session:
    session.headers.update({
        "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
        })
    url = "http://127.0.0.1:9091/departments/201"
    r=session.get(url)

    if r.status_code !=200:
        msg = "[%d Error]%s 에러가 발생함" %(r.status_code, r.reason)
        raise Exception(msg)
    
    print(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 with requests.Session()as session:
#       2     session.headers.update({
#       3         "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36"
#       4         })
#       5     url = "http://127.0.0.1:9091/departments/201"
#
# NameError: name 'requests' is not defined

# %%
r.encoding = "utf-8"
my_dict = r.json()
my_dict
# Out:
# {'result': {'id': 201,
#   'dname': '전자공학과',
#   'loc': '공학관',
#   'phone': '051-125-4567',
#   'email': 'ee@myschool.ac.kr',
#   'established': 1985,
#   'homepage': 'http://ee.myschool.ac.kr'},
#  'timestamp': '2025-11-04 17:18:38'}

# %%
print("학과번호:",my_dict["result"]["id"])
print("학과이름:", my_dict["result"]["dname"])
print("위치", my_dict["result"]["loc"])
print("연락처:", my_dict["result"]["phone"])
print("이메일:", my_dict["result"]["email"])
print("설립연도:", my_dict["result"]["established"])
print("홈페이지:", my_dict["result"]["homepage"])
# Out:
# 학과번호: 201
# 학과이름: 전자공학과
# 위치 공학관
# 연락처: 051-125-4567
# 이메일: ee@myschool.ac.kr
# 설립연도: 1985
# 홈페이지: http://ee.myschool.ac.kr

# %%
params = {
    "dname":"홍지영",
    "loc":"아이티윌",
    "phone":"052-7788-9900",
    "email":"python@myschool.ac.kr",
    "established":2025,
    "homepage": "http://python.myschool.ac.kr"
}

# %%
with requests.Session()as session:
    session.headers.update({
        "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
        })
    url = "http://192.168.24.31:9091/departments"
    r=session.post(url, data=params)

    if r.status_code !=200:
        msg = "[%d Error]%s 에러가 발생함" %(r.status_code, r.reason)
        raise Exception(msg)
    
    print(r)
# Out:
# <Response [200]>

# %%
r.encoding = "utf-8"
my_dict = r.json()

print("학과번호:", my_dict["result"]["id"])
print("학과이름:", my_dict["result"]["dname"])
print("위치:", my_dict["result"]["loc"])
print("연락처:", my_dict["result"]["phone"])
print("이메일:", my_dict["result"]["email"])
print("설립년도:",my_dict["result"]["established"])
print("홈페이지:", my_dict["result"]["homepage"])

#저장된 신규 학과의 pk값을 별도로 저장한다.
new_pk = my_dict["result"]["id"]
# Out:
# 학과번호: 507
# 학과이름: 홍지영
# 위치: 아이티윌
# 연락처: 052-7788-9900
# 이메일: python@myschool.ac.kr
# 설립년도: 2025
# 홈페이지: http://python.myschool.ac.kr

# %%
params = {
    "dname":"hong jiyoung",
    "loc":"아이티윌",
    "phone":"052-7766-8899",
    "email":"ai@myschool.ac.kr",
    "established":2025,
    "homepage": "http://ai.myschool.ac.kr"
}

# %%
with requests.Session()as session:
    session.headers.update({
        "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
        })
    url = "http://192.168.24.31:9091/departments/%d"%new_pk
    r=session.put(url, data=params)

    if r.status_code !=200:
        msg = "[%d Error]%s 에러가 발생함" %(r.status_code, r.reason)
        raise Exception(msg)
    
    print(r)
# Out:
# <Response [200]>

# %%
r.encoding = "utf-8"
my_dict = r.json()

print("학과번호:", my_dict["result"]["id"])
print("학과이름:", my_dict["result"]["dname"])
print("위치:", my_dict["result"]["loc"])
print("연락처:", my_dict["result"]["phone"])
print("이메일:", my_dict["result"]["email"])
print("설립년도:",my_dict["result"]["established"])
print("홈페이지:", my_dict["result"]["homepage"])
# Out:
# 학과번호: 507
# 학과이름: hong jiyoung
# 위치: 아이티윌
# 연락처: 052-7766-8899
# 이메일: ai@myschool.ac.kr
# 설립년도: 2025
# 홈페이지: http://ai.myschool.ac.kr

# %%
with requests.Session()as session:
    session.headers.update({
        "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
        })
    url = "http://192.168.24.31:9091/departments/%d"%new_pk
    r=session.delete(url)

    if r.status_code !=200:
        msg = "[%d Error]%s 에러가 발생함" %(r.status_code, r.reason)
        raise Exception(msg)
    
    print(r)
# Out:
# <Response [200]>

# %%
r.encoding = "utf-8"
my_dict=r.json()
my_dict
# Out:
# {'timestamp': '2025-11-04 18:03:24'}
