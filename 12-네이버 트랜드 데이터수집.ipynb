# %%
import requests
import json
import datetime as dt
from pandas import DataFrame

# %%
#요청 url
url = "https://openapi.naver.com/v1/datalab/search" 

#네이버 인증키
clientId="koEii3LooGeLPAI2sLjY"
clientSecret ="yjWURvCnRg"

#날짜 변수 생성(오늘날짜와 1년전 날짜)
now = dt.datetime.now()
today = now.strftime("%Y-%m-%d")
startDateDelta = now - dt.timedelta(days=365)
startDate = startDateDelta.strftime("%Y-%m-%d")

# %%
data = {
    "starDate" : startDate,
    "endDate" : today,
    "timeUnit" : "date",
    "keywordGroups": [
        {"groupName" : "Benz", #검색 주제
        #주제와 관련된 검색어
        "keywords" :["벤츠","e클래스","s클래스","c클래스","벤츠cls"]
    },
    {
        "groupName" : "BMW",
        "keywords" : ["BMW","5시리즈","x5","x7","x3"]
    },
    {
        "groupName" : "AUDI",
        "keywords" : ["아우디", "a6","e트론", "a7","q5"]
    }
]
}

# %%
with requests.Session()as session:
    session.headers.update({
        "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "X-Naver-Client-id": koEii3LooGeLPAI2sLjY,
        "X-Naver-Client-Secret":yjWURvCnRg
        })
  

    r=session.post(url,data=json.dumps(data))

    if r.status_code !=200:
        msg = "[%d Error]%s 에러가 발생함" %(r.status_code, r.reason)
        raise Exception(msg)
    
    print(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 with requests.Session()as session:
#       2     session.headers.update({
#       3         "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
# ----> 4         "X-Naver-Client-id": koEii3LooGeLPAI2sLjY,
#       5         "X-Naver-Client-Secret":yjWURvCnRg
#       6         })
#       9     r=session.post(url,data=json.dumps(data))
#      11     if r.status_code !=200:
#
# NameError: name 'koEii3LooGeLPAI2sLjY' is not defined
