# %%
from hossam import load_data
from matplotlib import pyplot as plt
from matplotlib import font_manager as fm
import seaborn as sb

# %%
origin = load_data('trffic_acc')
origin
# Out:
# trffic_acc는 존재하지 않는 데이터에 대한 요청입니다.
